# %%
import scipy.optimize as opt
import scipy.special as spec
import numpy as np
from math import *
import matplotlib.pyplot as plt
from DataSet import generateDataSet
from igraph import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')
from igraph import *
from DataSet import generateDataSet
import copy

# %% [markdown]
# ### Toy Example

# %%
n = 6
K = 2
p = 2

# %%
g = Graph(directed=True)
g.add_vertices(n)
listEdge = [(1,2),(1,3),(2,1),(2,3),(3,1),(3,2),(4,5),(4,6),(5,4),(5,6),(6,4),(6,5)]
for i in range(len(listEdge)):
    g.add_edge(listEdge[i][0] - 1,listEdge[i][1] - 1, width= ((i + 1) % 2) + 1 )
g.vs["label"] = [i + 1 for i in range(n)]
#colors = ["red", "green", (0.02, 0.6, 0.96)]
g.vs["color"] = ["green","green","green","blue", "blue", "blue"]
out = plot(g)
out.save("PlotToyExampleFinal.png")
out
